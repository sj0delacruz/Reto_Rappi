# %%
# !unzip data.zip

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 9043, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 9043 (delta 0), reused 0 (delta 0), pack-reused 9042
# Receiving objects: 100% (9043/9043), 9.69 MiB | 23.74 MiB/s, done.
# Resolving deltas: 100% (6276/6276), done.

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
# !python train.py --img 640 --batch 10 --epochs 100 --data /content/data/dataset0/config/dataset0.yaml --weights yolov5s.pt
# Out:
# ...
# 100% 755k/755k [00:00<00:00, 18.7MB/s]
# train: weights=yolov5s.pt, cfg=, data=/content/data/dataset0/config/dataset0.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=100, batch_size=10, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, entity=None, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=100
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v5.0-449-g9ef9494 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# ...

# %%
# !python train.py --img 640 --batch 5 --epochs 50 --data /content/data/dataset0/config/dataset0.yaml --weights /content/yolov5/runs/train/exp/weights/best.pt

# %%
# !apt install tesseract-ocr
# !pip install pytesseract

# %%
import pytesseract
from PIL import Image
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(9,6))
plt.imshow(Image.open('/content/data/dataset0/images/valid/img57.png'))
plt.axis(False)
plt.show()

extractedInformation = pytesseract.image_to_string(Image.open('/content/data/dataset0/images/valid/img57.png'))

print(extractedInformation)

# %%
# !python detect.py --save-txt --weights /content/yolov5/runs/train/exp/weights/best.pt --source /content/data/dataset0/images/valid/img57.png
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/data/dataset0/images/valid/img57.png, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-449-g9ef9494 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7056607 parameters, 0 gradients, 16.3 GFLOPs
# image 1/1 /content/data/dataset0/images/valid/img57.png: 640x288 1 id_colombia_front, Done. (0.020s)
# Speed: 0.4ms pre-process, 19.9ms inference, 2.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2
# 1 labels saved to runs/detect/exp2/labels

# %%
from glob import glob
import numpy as np

labels_names=np.loadtxt('/content/data/dataset0/labels/labels.txt',str)
root_labels_path = '/content/yolov5/runs/detect/exp2/labels/' #roca validar
labels_paths = glob(root_labels_path+'*.txt')
for labels_path in labels_paths:
  targets = np.loadtxt(labels_path, ndmin=2)
  img_path=labels_path.replace('yolov5/runs/detect/exp2/labels', 'data/dataset0/images/valid').replace('txt', 'png')
  img = Image.open(img_path)
  for n, i in enumerate(targets):
    img_cropped=img.crop( ((i[1]-i[3]/2)*img.width, (i[2]-i[4]/2)*img.height, (i[1]+i[3]/2)*img.width, (i[2]+i[4]/2)*img.height) )
    img_cropped.save(img_path.replace('dataset0/images/valid', 'dataset1/images/train_augmented').replace('.png', '_'+labels_names[n]+'.png'))

# %%
fig = plt.figure(figsize=(9,6))
plt.imshow(Image.open('/content/data/dataset1/images/train_augmented/img57_id_colombia_front.png'))
plt.axis(False)
plt.show()

extractedInformation = pytesseract.image_to_string(Image.open('/content/data/dataset1/images/train_augmented/img57_id_colombia_front.png'))

print(extractedInformation)

# %%
# !python train.py --img 640 --batch 5 --epochs 10 --data /content/data/dataset1/config/dataset1.yaml --weights yolov5s.pt

# %%
# !python train.py --img 640 --batch 10 --epochs 150 --data /content/data/dataset1/config/id.yaml --weights /content/yolov5/runs/train/exp4/weights/best.pt

# %%
# !python train.py --img 640 --batch 4 --epochs 100 --data /content/data/dataset1/config/id.yaml --weights /content/yolov5/runs/train/exp5/weights/best.pt

# %%
# !python detect.py --save-txt --weights /content/data/dataset1/weights/best.pt --source /content/data/dataset0/images/valid/img57.png
# Out:
# detect: weights=['/content/data/dataset1/weights/best.pt'], source=/content/data/dataset0/images/valid/img57.png, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-449-g9ef9494 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7067395 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/data/dataset0/images/valid/img57.png: 640x288 2 namess, 2 last_namess, Done. (0.020s)
# Speed: 0.4ms pre-process, 20.1ms inference, 2.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3
# 1 labels saved to runs/detect/exp3/labels

# %%
# !python detect.py --save-txt --weights /content/data/dataset1/weights/best.pt --source /content/data/dataset1/images/train_augmented/img57_id_colombia_front.png
# Out:
# detect: weights=['/content/data/dataset1/weights/best.pt'], source=/content/data/dataset1/images/train_augmented/img57_id_colombia_front.png, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-449-g9ef9494 torch 1.9.0+cu102 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7067395 parameters, 0 gradients, 16.4 GFLOPs
# image 1/1 /content/data/dataset1/images/train_augmented/img57_id_colombia_front.png: 384x640 1 names, 1 last_names, 1 country, Done. (0.025s)
# Speed: 0.4ms pre-process, 24.6ms inference, 2.1ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4
# 1 labels saved to runs/detect/exp4/labels

# %%
labels_names=np.loadtxt('/content/data/dataset1/labels/labels.txt',str)
root_labels_path = '/content/yolov5/runs/detect/exp4/labels/' #roca validar
labels_paths = glob(root_labels_path+'*.txt')
for labels_path in labels_paths:
  targets = np.loadtxt(labels_path, ndmin=2)
  img_path=labels_path.replace('yolov5/runs/detect/exp4/labels', 'data/dataset1/images/train_augmented').replace('txt', 'png')
  img = Image.open(img_path)
  for n, i in enumerate(targets):
    img_cropped=img.crop( ((i[1]-i[3]/2)*img.width, (i[2]-i[4]/2)*img.height, (i[1]+i[3]/2)*img.width, (i[2]+i[4]/2)*img.height) )
    img_cropped.save(img_path.replace('dataset1/images/train_augmented', 'dataset2').replace('.png', '_'+labels_names[int(i[0])]+'.png'))

# %%
fig = plt.figure(figsize=(9,6))
plt.imshow(Image.open('/content/data/dataset2/img57_id_colombia_front_last_names.png'))
plt.axis(False)
plt.show()

extractedInformation = pytesseract.image_to_string(Image.open('/content/data/dataset2/img57_id_colombia_front_last_names.png'))

print(extractedInformation.split('\n')[0])
